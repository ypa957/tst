# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# %matplotlib inline

plt.plot([1,2,3], [4,5,5])
plt.plot([1,2,3], [6,6,6])
plt.xlabel("X_axis")
plt.ylabel("Y_axis")
plt.title("P's Analyst")
plt.savefig("./ypa.png")
